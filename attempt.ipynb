# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("G:/diploma/Glow/_63001.txt", delimiter = " ", index_col = 0, parse_dates = True,
                  names = ["my_datetime", "data"])

# %%
#data = data.rename(columns={"date.utc": "datetime"})

# %%
data.head()
# Out:
#                            data
# my_datetime
# 2019-01-01 10:30:02  178.566174
# 2019-01-01 10:55:34  172.039337
# 2019-01-01 11:21:07  126.430739
# 2019-01-01 11:46:32   98.456247
# 2019-01-01 12:11:49   77.499696

# %%
data.plot()
# Out:
# <Axes: xlabel='my_datetime'>
